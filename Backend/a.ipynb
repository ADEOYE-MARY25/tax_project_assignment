# %%
from langchain_community.vectorstors import chroma
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain_community.vectorstors import chroma
#
# ModuleNotFoundError: No module named 'langchain_community.vectorstors'

# %%
from langchain_community.vectorstores import Chroma
# Out:
# c:\Users\HP\Desktop\tax_project_assignment\_env\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined
